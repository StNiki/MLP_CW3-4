# %%
import pickle as pcl
import os 
import matplotlib
import os
import tensorflow as tf
import datetime
from collections import OrderedDict
import numpy as np
import pickle as pcl
import matplotlib.pyplot as plt
from collections import OrderedDict
# %matplotlib inline
plt.style.use('ggplot')

# %%
def read_from_file(newfile):
    run_info = pcl.load(open(newfile,'r'))
    return run_info
# 4 arrays te,ta,ve,va

# %%
def plot_(te,ta,ve,va):
        fig = plt.figure(figsize=(12, 12))
        ax1 = fig.add_subplot(2, 2, 1)
        ax2 = fig.add_subplot(2, 2, 2)
        ax1.plot(te, label='te')
        ax2.plot(ta, label='ta')
        ax1.legend(loc=2,prop={'size':8})
        ax1.grid()
        ax1.set_xlabel('Epoch number')
        ax1.set_ylabel('Training Error')
        #ax1.set_yscale('log')
        ax2.legend(loc=2,prop={'size':8})
        ax2.set_xlabel('Epoch number')
        ax2.set_ylabel('Training Accuracy')
        #ax2.set_yscale('log')
        ax2.grid()
        ax3 = fig.add_subplot(2, 2, 3)
        ax4 = fig.add_subplot(2, 2, 4)
        ax3.plot(ve, label='ve')
        ax4.plot(va, label='va')
        ax3.legend(loc=2,prop={'size':8})
        ax3.grid()
        ax3.set_xlabel('Epoch number')
        ax3.set_ylabel('Validation Error')
        #ax3.set_yscale('log')
        ax4.legend(loc=2,prop={'size':8})
        ax4.set_xlabel('Epoch number')
        ax4.set_ylabel('Validation Accuracy')
        #ax4.set_yscale('log')
        ax4.grid()
        fig.tight_layout()
        fig.savefig('test.pdf',dpi=200)

# %%
def get_(run_info):
    te = []
    ve = []
    va = []
    ta = []
    for i,arr in enumerate(run_info):
        if i==0:
            te=arr
        elif i==1:
            ta=arr
        elif i==2:
            ve=arr
        elif i==3:
            va=arr
    return te,ta,ve,va

# %%
name = "../../res/base16_100.txt"
plot_(read_from_file(name))

# %%
path = '../../res'
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if "base" in f:
        print(f)
# Out:
# ../../res/base16_100.txt
# ../../res/base16.txt
# ../../res/base-32_100.txt
# ../../res/base-32_10.txt
# ../../res/base6CC-16_10.txt
# ../../res/base6CC-32_10.txt
# ../../res/base6CC-8_10.txt
# ../../res/base6CCK5-16_10.txt
# ../../res/base6CCK5-8_10.txt
# ../../res/base6CNN-16_100.txt
# ../../res/base6CNN-32_100.txt
# ../../res/base6CNN-8_100.txt
# ../../res/base6CNN-drop-fc0.1_100.txt
# ../../res/base6CNN-drop-fc0.1_10.txt
# ../../res/base6CNN-drop-fc0.25_100.txt
# ../../res/base6CNN-drop-fc0.25_10.txt
# ../../res/base6CNN-drop-fc0.5_100.txt
# ../../res/base6CNN-drop-fc0.5_10.txt
# ../../res/base6CNN-drop-fc0.75_100.txt
# ../../res/base6CNN-drop-fc0.75_10.txt
# ../../res/base6CNN-drop-fc0.9_100.txt
# ../../res/base6CNN-drop-fc0.9_10.txt
# ../../res/base6CNNK5-16_100.txt
# ../../res/base6CNNK5-8_100.txt
# ../../res/base6CNN-L20.0001_100.txt
# ../../res/base6CNN-L20.0001_10.txt
# ../../res/base8_100.txt
# ../../res/base6CNN-L20.001_100.txt
# ../../res/base6CNN-L20.001_10.txt
# ...

# %%
plot_(te,ta,ve,va)

# %%
path = '../../res'

# %%
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    print(f)
    #print(get_(read_from_file(f))[3][29])
# Out:
# ../../res/base16_100.txt
# ../../res/base16.txt
# ../../res/base-32_100.txt
# ../../res/base-32_10.txt
# ../../res/base6CC-16_10.txt
# ../../res/base6CC-32_10.txt
# ../../res/base6CC-8_10.txt
# ../../res/base6CCK5-16_10.txt
# ../../res/base6CCK5-8_10.txt
# ../../res/base6CNN-16_100.txt
# ../../res/base6CNN-32_100.txt
# ../../res/base6CNN-8_100.txt
# ../../res/base6CNN-drop-fc0.1_100.txt
# ../../res/base6CNN-drop-fc0.1_10.txt
# ../../res/base6CNN-drop-fc0.25_100.txt
# ../../res/base6CNN-drop-fc0.25_10.txt
# ../../res/base6CNN-drop-fc0.5_100.txt
# ../../res/base6CNN-drop-fc0.5_10.txt
# ../../res/base6CNN-drop-fc0.75_100.txt
# ../../res/base6CNN-drop-fc0.75_10.txt
# ../../res/base6CNN-drop-fc0.9_100.txt
# ../../res/base6CNN-drop-fc0.9_10.txt
# ../../res/base6CNNK5-16_100.txt
# ../../res/base6CNNK5-8_100.txt
# ../../res/base6CNN-L20.0001_100.txt
# ../../res/base6CNN-L20.0001_10.txt
# ../../res/base8_100.txt
# ../../res/base6CNN-L20.001_100.txt
# ../../res/base6CNN-L20.001_10.txt
# ...

# %%
## CIFAR 10

#base   8-16-32
#baseK5 8-16-32
#base6CNN

    #drop-fc 0.1
    #drop-fc 0.25
    #drop-fc 0.5
    #drop-fc 0.75
    #drop-fc 0.9

    #drop 0.1
    #drop 0.25
    #drop 0.5
    #drop 0.75
    #drop 0.9

    #L2 0.1
    #L2 0.01
    #L2 0.001
    #L2 0.0001

    #DA-flip_rl
    #DA-flip_ud
    #DA-hue
    #DA-constrast
    #DA-saturation
    #DA-brightness

## CIFAR 100

#..

# %%
te0= np.zeros((1,30))
ta0= np.zeros((1,30))
ve0= np.zeros((1,30))
va0= np.zeros((1,30))
te1= np.zeros((1,30))
ta1= np.zeros((1,30))
ve1= np.zeros((1,30))
va1= np.zeros((1,30))
te2= np.zeros((1,30))
ta2= np.zeros((1,30))
ve2= np.zeros((1,30))
va2= np.zeros((1,30))
te3= np.zeros((1,30))
ta3= np.zeros((1,30))
ve3= np.zeros((1,30))
va3= np.zeros((1,30))
te4= np.zeros((1,30))
ta4= np.zeros((1,30))
ve4= np.zeros((1,30))
va4= np.zeros((1,30))
i = 0
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if "base-drop" in f:
        if "_100" not in f:
            if "drop-fc" in f:
                if i==0:
                    te0,ta0,ve0,va0 = get_(read_from_file(f))
                if i==1:
                    te1,ta1,ve1,va1 = get_(read_from_file(f))
                if i==2:
                    te2,ta2,ve2,va2 = get_(read_from_file(f))
                if i==3:
                    te3,ta3,ve3,va3 = get_(read_from_file(f))
                if i==4:
                    te4,ta4,ve4,va4 = get_(read_from_file(f))
                i+=1
                
fig = plt.figure(figsize=(8, 4))
ax1 = fig.add_subplot(1, 2, 1)
#ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(te0, label='0.1')
ax1.plot(te1, label='0.25')
ax1.plot(te2, label='0.5')
ax1.plot(te3, label='0.75')
ax1.plot(te4, label='0.9')

#ax2.plot(ta0, label='0.1')
#ax2.plot(ta1, label='0.25')
#ax2.plot(ta2, label='0.5')
#ax2.plot(ta3, label='0.75')
#ax2.plot(ta4, label='0.9')

ax1.legend(loc=1,prop={'size':8})
#ax1.grid()
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Training Error')
#ax1.set_yscale('log')

#ax2.legend(loc=2,prop={'size':8})
#ax2.set_xlabel('Epoch number')
#ax2.set_ylabel('Training Accuracy')
#ax2.set_yscale('log')
#ax2.grid()

ax3 = fig.add_subplot(1, 2, 2)
#ax4 = fig.add_subplot(2, 2, 4)

ax3.plot(ve0, label='0.1')
ax3.plot(ve1, label='0.25')
ax3.plot(ve2, label='0.5')
ax3.plot(ve3, label='0.75')
ax3.plot(ve4, label='0.9')

#ax4.plot(va0, label='0.1')
#ax4.plot(va1, label='0.25')
#ax4.plot(va2, label='0.5')
#ax4.plot(va3, label='0.75')
#ax4.plot(va4, label='0.9')

ax3.legend(loc=2,prop={'size':8})
#ax3.grid()
ax3.set_xlabel('Epoch number')
ax3.set_ylabel('Validation Error')
#ax3.set_yscale('log')
#ax4.legend(loc=2,prop={'size':8})
#ax4.set_xlabel('Epoch number')
#ax4.set_ylabel('Validation Accuracy')
#ax4.set_yscale('log')
#ax4.grid()
fig.tight_layout()
fig.savefig('drop-fc_10.pdf',dpi=200)


print("Dropout 0.1")
print('    final error(train) = {0}').format(te0[29])
print('    final error(valid) = {0}').format(ve0[29])
print('    final acc(train)   = {0}').format(ta0[29])
print('    final acc(valid)   = {0}').format(va0[29])
print('-------------------------------------------------------------')

print("Dropout 0.25")
print('    final error(train) = {0}').format(te1[29])
print('    final error(valid) = {0}').format(ve1[29])
print('    final acc(train)   = {0}').format(ta1[29])
print('    final acc(valid)   = {0}').format(va1[29])
print('-------------------------------------------------------------')
            
print("Dropout 0.5")
print('    final error(train) = {0}').format(te2[29])
print('    final error(valid) = {0}').format(ve2[29])
print('    final acc(train)   = {0}').format(ta2[29])
print('    final acc(valid)   = {0}').format(va2[29])
print('-------------------------------------------------------------')
      
print("Dropout 0.75")
print('    final error(train) = {0}').format(te3[29])
print('    final error(valid) = {0}').format(ve3[29])
print('    final acc(train)   = {0}').format(ta3[29])
print('    final acc(valid)   = {0}').format(va3[29])
print('-------------------------------------------------------------')
      
print("Dropout 0.9")
print('    final error(train) = {0}').format(te4[29])
print('    final error(valid) = {0}').format(ve4[29])
print('    final acc(train)   = {0}').format(ta4[29])
print('    final acc(valid)   = {0}').format(va4[29])
print('-------------------------------------------------------------')
# Out:
# Dropout 0.1
#     final error(train) = 1.25041879818
#     final error(valid) = 1.42606389523
#     final acc(train)   = 0.555175001994
#     final acc(valid)   = 0.514999985695
# -------------------------------------------------------------
# Dropout 0.25
#     final error(train) = 0.840998655222
#     final error(valid) = 1.4032535553
#     final acc(train)   = 0.697975004725
#     final acc(valid)   = 0.560599982738
# -------------------------------------------------------------
# Dropout 0.5
#     final error(train) = 0.445879372098
#     final error(valid) = 1.89721369743
#     final acc(train)   = 0.836099993438
#     final acc(valid)   = 0.557799994946
# -------------------------------------------------------------
# Dropout 0.75
#     final error(train) = 0.197213728596
#     final error(valid) = 2.63915133476
#     final acc(train)   = 0.929649997428
#     final acc(valid)   = 0.54699999094
# -------------------------------------------------------------
# Dropout 0.9
# ...

# %%
te0= np.zeros((1,30))
ta0= np.zeros((1,30))
ve0= np.zeros((1,30))
va0= np.zeros((1,30))
te1= np.zeros((1,30))
ta1= np.zeros((1,30))
ve1= np.zeros((1,30))
va1= np.zeros((1,30))
te2= np.zeros((1,30))
ta2= np.zeros((1,30))
ve2= np.zeros((1,30))
va2= np.zeros((1,30))
te3= np.zeros((1,30))
ta3= np.zeros((1,30))
ve3= np.zeros((1,30))
va3= np.zeros((1,30))
te4= np.zeros((1,30))
ta4= np.zeros((1,30))
ve4= np.zeros((1,30))
va4= np.zeros((1,30))
i = 0
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if "base-drop" in f:
        if "_100" in f:
            if "drop-fc" in f:
                if i==0:
                    te0,ta0,ve0,va0 = get_(read_from_file(f))
                if i==1:
                    te1,ta1,ve1,va1 = get_(read_from_file(f))
                if i==2:
                    te2,ta2,ve2,va2 = get_(read_from_file(f))
                if i==3:
                    te3,ta3,ve3,va3 = get_(read_from_file(f))
                if i==4:
                    te4,ta4,ve4,va4 = get_(read_from_file(f))
                i+=1
                
fig = plt.figure(figsize=(8, 4))
ax1 = fig.add_subplot(1, 2, 1)
#ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(te0, label='0.1')
ax1.plot(te1, label='0.25')
ax1.plot(te2, label='0.5')
ax1.plot(te3, label='0.75')
ax1.plot(te4, label='0.9')

#ax2.plot(ta0, label='0.1')
#ax2.plot(ta1, label='0.25')
#ax2.plot(ta2, label='0.5')
#ax2.plot(ta3, label='0.75')
#ax2.plot(ta4, label='0.9')

ax1.legend(loc=1,prop={'size':8})
#ax1.grid()
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Training Error')
#ax1.set_yscale('log')

#ax2.legend(loc=2,prop={'size':8})
#ax2.set_xlabel('Epoch number')
#ax2.set_ylabel('Training Accuracy')
#ax2.set_yscale('log')
#ax2.grid()

ax3 = fig.add_subplot(1, 2, 2)
#ax4 = fig.add_subplot(2, 2, 4)

ax3.plot(ve0, label='0.1')
ax3.plot(ve1, label='0.25')
ax3.plot(ve2, label='0.5')
ax3.plot(ve3, label='0.75')
ax3.plot(ve4, label='0.9')

#ax4.plot(va0, label='0.1')
#ax4.plot(va1, label='0.25')
#ax4.plot(va2, label='0.5')
#ax4.plot(va3, label='0.75')
#ax4.plot(va4, label='0.9')

ax3.legend(loc=2,prop={'size':8})
#ax3.grid()
ax3.set_xlabel('Epoch number')
ax3.set_ylabel('Validation Error')
#ax3.set_yscale('log')
#ax4.legend(loc=2,prop={'size':8})
#ax4.set_xlabel('Epoch number')
#ax4.set_ylabel('Validation Accuracy')
#ax4.set_yscale('log')
#ax4.grid()
fig.tight_layout()
fig.savefig('drop-fc_100.pdf',dpi=200)


print("Dropout 0.1")
print('    final error(train) = {0}').format(te0[29])
print('    final error(valid) = {0}').format(ve0[29])
print('    final acc(train)   = {0}').format(ta0[29])
print('    final acc(valid)   = {0}').format(va0[29])
print('-------------------------------------------------------------')

print("Dropout 0.25")
print('    final error(train) = {0}').format(te1[29])
print('    final error(valid) = {0}').format(ve1[29])
print('    final acc(train)   = {0}').format(ta1[29])
print('    final acc(valid)   = {0}').format(va1[29])
print('-------------------------------------------------------------')
            
print("Dropout 0.5")
print('    final error(train) = {0}').format(te2[29])
print('    final error(valid) = {0}').format(ve2[29])
print('    final acc(train)   = {0}').format(ta2[29])
print('    final acc(valid)   = {0}').format(va2[29])
print('-------------------------------------------------------------')
      
print("Dropout 0.75")
print('    final error(train) = {0}').format(te3[29])
print('    final error(valid) = {0}').format(ve3[29])
print('    final acc(train)   = {0}').format(ta3[29])
print('    final acc(valid)   = {0}').format(va3[29])
print('-------------------------------------------------------------')
      
print("Dropout 0.9")
print('    final error(train) = {0}').format(te4[29])
print('    final error(valid) = {0}').format(ve4[29])
print('    final acc(train)   = {0}').format(ta4[29])
print('    final acc(valid)   = {0}').format(va4[29])
print('-------------------------------------------------------------')
# Out:
# Dropout 0.1
#     final error(train) = 2.18432556182
#     final error(valid) = 3.50254797935
#     final acc(train)   = 0.427274999525
#     final acc(valid)   = 0.249699994922
# -------------------------------------------------------------
# Dropout 0.25
#     final error(train) = 0.410520772347
#     final error(valid) = 6.48205137253
#     final acc(train)   = 0.875049995333
#     final acc(valid)   = 0.229599997401
# -------------------------------------------------------------
# Dropout 0.5
#     final error(train) = 0.189054930257
#     final error(valid) = 7.92286729813
#     final acc(train)   = 0.945024998412
#     final acc(valid)   = 0.217700004578
# -------------------------------------------------------------
# Dropout 0.75
#     final error(train) = 0.0914719896459
#     final error(valid) = 8.51060676575
#     final acc(train)   = 0.974275002033
#     final acc(valid)   = 0.239299997687
# -------------------------------------------------------------
# Dropout 0.9
# ...

# %%
te0= np.zeros((1,30))
ta0= np.zeros((1,30))
ve0= np.zeros((1,30))
va0= np.zeros((1,30))
te1= np.zeros((1,30))
ta1= np.zeros((1,30))
ve1= np.zeros((1,30))
va1= np.zeros((1,30))
te2= np.zeros((1,30))
ta2= np.zeros((1,30))
ve2= np.zeros((1,30))
va2= np.zeros((1,30))
te3= np.zeros((1,30))
ta3= np.zeros((1,30))
ve3= np.zeros((1,30))
va3= np.zeros((1,30))
te4= np.zeros((1,30))
ta4= np.zeros((1,30))
ve4= np.zeros((1,30))
va4= np.zeros((1,30))
i = 0
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if "base-drop" in f:
        if "_100" not in f:
            if "drop-fc" not in f:
                if i==0:
                    te0,ta0,ve0,va0 = get_(read_from_file(f))
                if i==1:
                    te1,ta1,ve1,va1 = get_(read_from_file(f))
                if i==2:
                    te2,ta2,ve2,va2 = get_(read_from_file(f))
                if i==3:
                    te3,ta3,ve3,va3 = get_(read_from_file(f))
                if i==4:
                    te4,ta4,ve4,va4 = get_(read_from_file(f))
                i+=1
                
fig = plt.figure(figsize=(8, 4))
ax1 = fig.add_subplot(1, 2, 1)
#ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(te0, label='0.1')
ax1.plot(te1, label='0.25')
ax1.plot(te2, label='0.5')
ax1.plot(te3, label='0.75')
ax1.plot(te4, label='0.9')

#ax2.plot(ta0, label='0.1')
#ax2.plot(ta1, label='0.25')
#ax2.plot(ta2, label='0.5')
#ax2.plot(ta3, label='0.75')
#ax2.plot(ta4, label='0.9')

ax1.legend(loc=2,prop={'size':8})
#ax1.grid()
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Training Error')
#ax1.set_yscale('log')

#ax2.legend(loc=2,prop={'size':8})
#ax2.set_xlabel('Epoch number')
#ax2.set_ylabel('Training Accuracy')
#ax2.set_yscale('log')
#ax2.grid()

ax3 = fig.add_subplot(1, 2, 2)
#ax4 = fig.add_subplot(2, 2, 4)

ax3.plot(ve0, label='0.1')
ax3.plot(ve1, label='0.25')
ax3.plot(ve2, label='0.5')
ax3.plot(ve3, label='0.75')
ax3.plot(ve4, label='0.9')

#ax4.plot(va0, label='0.1')
#ax4.plot(va1, label='0.25')
#ax4.plot(va2, label='0.5')
#ax4.plot(va3, label='0.75')
#ax4.plot(va4, label='0.9')

ax3.legend(loc=2,prop={'size':8})
#ax3.grid()
ax3.set_xlabel('Epoch number')
ax3.set_ylabel('Validation Error')
#ax3.set_yscale('log')
#ax4.legend(loc=2,prop={'size':8})
#ax4.set_xlabel('Epoch number')
#ax4.set_ylabel('Validation Accuracy')
#ax4.set_yscale('log')
#ax4.grid()
fig.tight_layout()
fig.savefig('drop_10.pdf',dpi=200)


print("Dropout 0.1")
print('    final error(train) = {0}').format(te0[29])
print('    final error(valid) = {0}').format(ve0[29])
print('    final acc(train)   = {0}').format(ta0[29])
print('    final acc(valid)   = {0}').format(va0[29])
print('-------------------------------------------------------------')

print("Dropout 0.25")
print('    final error(train) = {0}').format(te1[29])
print('    final error(valid) = {0}').format(ve1[29])
print('    final acc(train)   = {0}').format(ta1[29])
print('    final acc(valid)   = {0}').format(va1[29])
print('-------------------------------------------------------------')
            
print("Dropout 0.5")
print('    final error(train) = {0}').format(te2[29])
print('    final error(valid) = {0}').format(ve2[29])
print('    final acc(train)   = {0}').format(ta2[29])
print('    final acc(valid)   = {0}').format(va2[29])
print('-------------------------------------------------------------')
      
print("Dropout 0.75")
print('    final error(train) = {0}').format(te3[29])
print('    final error(valid) = {0}').format(ve3[29])
print('    final acc(train)   = {0}').format(ta3[29])
print('    final acc(valid)   = {0}').format(va3[29])
print('-------------------------------------------------------------')
      
print("Dropout 0.9")
print('    final error(train) = {0}').format(te4[29])
print('    final error(valid) = {0}').format(ve4[29])
print('    final acc(train)   = {0}').format(ta4[29])
print('    final acc(valid)   = {0}').format(va4[29])
print('-------------------------------------------------------------')
# Out:
# Dropout 0.1
#     final error(train) = 2.30289172918
#     final error(valid) = 2.30273938179
#     final acc(train)   = 0.100599999307
#     final acc(valid)   = 0.0991000011563
# -------------------------------------------------------------
# Dropout 0.25
#     final error(train) = 1.75427041084
#     final error(valid) = 1.77067935467
#     final acc(train)   = 0.363350000326
#     final acc(valid)   = 0.365000009537
# -------------------------------------------------------------
# Dropout 0.5
#     final error(train) = 1.29269572489
#     final error(valid) = 1.38251852989
#     final acc(train)   = 0.53970000077
#     final acc(valid)   = 0.51289999485
# -------------------------------------------------------------
# Dropout 0.75
#     final error(train) = 0.826615845226
#     final error(valid) = 1.397387743
#     final acc(train)   = 0.702800003588
#     final acc(valid)   = 0.560800015926
# -------------------------------------------------------------
# Dropout 0.9
# ...

# %%
te0= np.zeros((1,30))
ta0= np.zeros((1,30))
ve0= np.zeros((1,30))
va0= np.zeros((1,30))
te1= np.zeros((1,30))
ta1= np.zeros((1,30))
ve1= np.zeros((1,30))
va1= np.zeros((1,30))
te2= np.zeros((1,30))
ta2= np.zeros((1,30))
ve2= np.zeros((1,30))
va2= np.zeros((1,30))
te3= np.zeros((1,30))
ta3= np.zeros((1,30))
ve3= np.zeros((1,30))
va3= np.zeros((1,30))
te4= np.zeros((1,30))
ta4= np.zeros((1,30))
ve4= np.zeros((1,30))
va4= np.zeros((1,30))
i = 0
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if "base-drop" in f:
        if "_100" in f:
            if "drop-fc" not in f:
                if i==0:
                    te0,ta0,ve0,va0 = get_(read_from_file(f))
                if i==1:
                    te1,ta1,ve1,va1 = get_(read_from_file(f))
                if i==2:
                    te2,ta2,ve2,va2 = get_(read_from_file(f))
                if i==3:
                    te3,ta3,ve3,va3 = get_(read_from_file(f))
                if i==4:
                    te4,ta4,ve4,va4 = get_(read_from_file(f))
                i+=1
                
fig = plt.figure(figsize=(8, 4))
ax1 = fig.add_subplot(1, 2, 1)
#ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(te0, label='0.1')
ax1.plot(te1, label='0.25')
ax1.plot(te2, label='0.5')
ax1.plot(te3, label='0.75')
ax1.plot(te4, label='0.9')

#ax2.plot(ta0, label='0.1')
#ax2.plot(ta1, label='0.25')
#ax2.plot(ta2, label='0.5')
#ax2.plot(ta3, label='0.75')
#ax2.plot(ta4, label='0.9')

ax1.legend(loc=2,prop={'size':8})
#ax1.grid()
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Training Error')
#ax1.set_yscale('log')

#ax2.legend(loc=2,prop={'size':8})
#ax2.set_xlabel('Epoch number')
#ax2.set_ylabel('Training Accuracy')
#ax2.set_yscale('log')
#ax2.grid()

ax3 = fig.add_subplot(1, 2, 2)
#ax4 = fig.add_subplot(2, 2, 4)

ax3.plot(ve0, label='0.1')
ax3.plot(ve1, label='0.25')
ax3.plot(ve2, label='0.5')
ax3.plot(ve3, label='0.75')
ax3.plot(ve4, label='0.9')

#ax4.plot(va0, label='0.1')
#ax4.plot(va1, label='0.25')
#ax4.plot(va2, label='0.5')
#ax4.plot(va3, label='0.75')
#ax4.plot(va4, label='0.9')

ax3.legend(loc=2,prop={'size':8})
#ax3.grid()
ax3.set_xlabel('Epoch number')
ax3.set_ylabel('Validation Error')
#ax3.set_yscale('log')
#ax4.legend(loc=2,prop={'size':8})
#ax4.set_xlabel('Epoch number')
#ax4.set_ylabel('Validation Accuracy')
#ax4.set_yscale('log')
#ax4.grid()
fig.tight_layout()
fig.savefig('drop_100.pdf',dpi=200)


print("Dropout 0.1")
print('    final error(train) = {0}').format(te0[29])
print('    final error(valid) = {0}').format(ve0[29])
print('    final acc(train)   = {0}').format(ta0[29])
print('    final acc(valid)   = {0}').format(va0[29])
print('-------------------------------------------------------------')

print("Dropout 0.25")
print('    final error(train) = {0}').format(te1[29])
print('    final error(valid) = {0}').format(ve1[29])
print('    final acc(train)   = {0}').format(ta1[29])
print('    final acc(valid)   = {0}').format(va1[29])
print('-------------------------------------------------------------')
            
print("Dropout 0.5")
print('    final error(train) = {0}').format(te2[29])
print('    final error(valid) = {0}').format(ve2[29])
print('    final acc(train)   = {0}').format(ta2[29])
print('    final acc(valid)   = {0}').format(va2[29])
print('-------------------------------------------------------------')
      
print("Dropout 0.75")
print('    final error(train) = {0}').format(te3[29])
print('    final error(valid) = {0}').format(ve3[29])
print('    final acc(train)   = {0}').format(ta3[29])
print('    final acc(valid)   = {0}').format(va3[29])
print('-------------------------------------------------------------')
      
print("Dropout 0.9")
print('    final error(train) = {0}').format(te4[29])
print('    final error(valid) = {0}').format(ve4[29])
print('    final acc(train)   = {0}').format(ta4[29])
print('    final acc(valid)   = {0}').format(va4[29])
print('-------------------------------------------------------------')
# Out:
# Dropout 0.1
#     final error(train) = 4.47318594635
#     final error(valid) = 4.47595930099
#     final acc(train)   = 0.0290749994107
#     final acc(valid)   = 0.0294000003487
# -------------------------------------------------------------
# Dropout 0.25
#     final error(train) = 4.60581582665
#     final error(valid) = 4.60517978668
#     final acc(train)   = 0.0078249998251
#     final acc(valid)   = 0.00999999977648
# -------------------------------------------------------------
# Dropout 0.5
#     final error(train) = 2.93303730428
#     final error(valid) = 3.28152394295
#     final acc(train)   = 0.271174999587
#     final acc(valid)   = 0.226099997759
# -------------------------------------------------------------
# Dropout 0.75
#     final error(train) = 2.13677693322
#     final error(valid) = 3.39332103729
#     final acc(train)   = 0.428624999207
#     final acc(valid)   = 0.259700000286
# -------------------------------------------------------------
# Dropout 0.9
# ...

# %%
te0= np.zeros((1,30))
ta0= np.zeros((1,30))
ve0= np.zeros((1,30))
va0= np.zeros((1,30))
te1= np.zeros((1,30))
ta1= np.zeros((1,30))
ve1= np.zeros((1,30))
va1= np.zeros((1,30))
te2= np.zeros((1,30))
ta2= np.zeros((1,30))
ve2= np.zeros((1,30))
va2= np.zeros((1,30))
te3= np.zeros((1,30))
ta3= np.zeros((1,30))
ve3= np.zeros((1,30))
va3= np.zeros((1,30))
#te4= np.zeros((1,30))
#ta4= np.zeros((1,30))
#ve4= np.zeros((1,30))
#va4= np.zeros((1,30))
i = 0
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if "base-L2" in f:
        if "_100" not in f:
            #if:
                if i==0:
                    te0,ta0,ve0,va0 = get_(read_from_file(f))
                if i==1:
                    te1,ta1,ve1,va1 = get_(read_from_file(f))
                if i==2:
                    te2,ta2,ve2,va2 = get_(read_from_file(f))
                if i==3:
                    te3,ta3,ve3,va3 = get_(read_from_file(f))
                #if i==4:
                #    te4,ta4,ve4,va4 = get_(read_from_file(f))
                i+=1
                
fig = plt.figure(figsize=(8, 4))
ax1 = fig.add_subplot(1, 2, 1)
#ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(te0, label='0.1')
ax1.plot(te1, label='0.01')
ax1.plot(te2, label='0.001')
ax1.plot(te3, label='0.0001')
#ax1.plot(te4, label='0.9')

#ax2.plot(ta0, label='0.1')
#ax2.plot(ta1, label='0.25')
#ax2.plot(ta2, label='0.5')
#ax2.plot(ta3, label='0.75')
#ax2.plot(ta4, label='0.9')

ax1.legend(loc=2,prop={'size':8})
#ax1.grid()
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Training Error')
ax1.set_yscale('log')

#ax2.legend(loc=2,prop={'size':8})
#ax2.set_xlabel('Epoch number')
#ax2.set_ylabel('Training Accuracy')
#ax2.set_yscale('log')
#ax2.grid()

ax3 = fig.add_subplot(1, 2, 2)
#ax4 = fig.add_subplot(2, 2, 4)

ax3.plot(ve0, label='0.1')
ax3.plot(ve1, label='0.01')
ax3.plot(ve2, label='0.001')
ax3.plot(ve3, label='0.0001')
#ax3.plot(ve4, label='0.9')

#ax4.plot(va0, label='0.1')
#ax4.plot(va1, label='0.25')
#ax4.plot(va2, label='0.5')
#ax4.plot(va3, label='0.75')
#ax4.plot(va4, label='0.9')

ax3.legend(loc=2,prop={'size':8})
#ax3.grid()
ax3.set_xlabel('Epoch number')
ax3.set_ylabel('Validation Error')
#ax3.set_yscale('log')
#ax4.legend(loc=2,prop={'size':8})
#ax4.set_xlabel('Epoch number')
#ax4.set_ylabel('Validation Accuracy')
#ax4.set_yscale('log')
#ax4.grid()
fig.tight_layout()
fig.savefig('L2_10.pdf',dpi=200)


print("L2 0.1")
print('    final error(train) = {0}').format(te0[29])
print('    final error(valid) = {0}').format(ve0[29])
print('    final acc(train)   = {0}').format(ta0[29])
print('    final acc(valid)   = {0}').format(va0[29])
print('-------------------------------------------------------------')

print("L2 0.01")
print('    final error(train) = {0}').format(te1[29])
print('    final error(valid) = {0}').format(ve1[29])
print('    final acc(train)   = {0}').format(ta1[29])
print('    final acc(valid)   = {0}').format(va1[29])
print('-------------------------------------------------------------')
            
print("L2 0.001")
print('    final error(train) = {0}').format(te2[29])
print('    final error(valid) = {0}').format(ve2[29])
print('    final acc(train)   = {0}').format(ta2[29])
print('    final acc(valid)   = {0}').format(va2[29])
print('-------------------------------------------------------------')
      
print("L2 0.0001")
print('    final error(train) = {0}').format(te3[29])
print('    final error(valid) = {0}').format(ve3[29])
print('    final acc(train)   = {0}').format(ta3[29])
print('    final acc(valid)   = {0}').format(va3[29])
print('-------------------------------------------------------------')
# Out:
# L2 0.1
#     final error(train) = 0.312354455572
#     final error(valid) = 2.68152880669
#     final acc(train)   = 0.964024999961
#     final acc(valid)   = 0.58630001545
# -------------------------------------------------------------
# L2 0.01
#     final error(train) = 0.673067278042
#     final error(valid) = 1.8205960989
#     final acc(train)   = 0.90214999564
#     final acc(valid)   = 0.575800001621
# -------------------------------------------------------------
# L2 0.001
#     final error(train) = 1.33898710333
#     final error(valid) = 1.16956269741
#     final acc(train)   = 0.610175003745
#     final acc(valid)   = 0.592299997807
# -------------------------------------------------------------
# L2 0.0001
#     final error(train) = 1.8782017459
#     final error(valid) = 1.76868999004
#     final acc(train)   = 0.380550000351
#     final acc(valid)   = 0.368600010872
# -------------------------------------------------------------

# %%
te0= np.zeros((1,30))
ta0= np.zeros((1,30))
ve0= np.zeros((1,30))
va0= np.zeros((1,30))
te1= np.zeros((1,30))
ta1= np.zeros((1,30))
ve1= np.zeros((1,30))
va1= np.zeros((1,30))
te2= np.zeros((1,30))
ta2= np.zeros((1,30))
ve2= np.zeros((1,30))
va2= np.zeros((1,30))
te3= np.zeros((1,30))
ta3= np.zeros((1,30))
ve3= np.zeros((1,30))
va3= np.zeros((1,30))
#te4= np.zeros((1,30))
#ta4= np.zeros((1,30))
#ve4= np.zeros((1,30))
#va4= np.zeros((1,30))
i = 0
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if "base-L2" in f:
        if "_100" in f:
            #if:
                if i==0:
                    te0,ta0,ve0,va0 = get_(read_from_file(f))
                if i==1:
                    te1,ta1,ve1,va1 = get_(read_from_file(f))
                if i==2:
                    te2,ta2,ve2,va2 = get_(read_from_file(f))
                if i==3:
                    te3,ta3,ve3,va3 = get_(read_from_file(f))
                #if i==4:
                #    te4,ta4,ve4,va4 = get_(read_from_file(f))
                i+=1
                
fig = plt.figure(figsize=(8, 4))
ax1 = fig.add_subplot(1, 2, 1)
#ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(te0, label='0.1')
ax1.plot(te1, label='0.01')
ax1.plot(te2, label='0.001')
ax1.plot(te3, label='0.0001')
#ax1.plot(te4, label='0.9')

#ax2.plot(ta0, label='0.1')
#ax2.plot(ta1, label='0.25')
#ax2.plot(ta2, label='0.5')
#ax2.plot(ta3, label='0.75')
#ax2.plot(ta4, label='0.9')

ax1.legend(loc=2,prop={'size':8})
#ax1.grid()
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Training Error')
ax1.set_yscale('log')

#ax2.legend(loc=2,prop={'size':8})
#ax2.set_xlabel('Epoch number')
#ax2.set_ylabel('Training Accuracy')
#ax2.set_yscale('log')
#ax2.grid()

ax3 = fig.add_subplot(1, 2, 2)
#ax4 = fig.add_subplot(2, 2, 4)

ax3.plot(ve0, label='0.1')
ax3.plot(ve1, label='0.01')
ax3.plot(ve2, label='0.001')
ax3.plot(ve3, label='0.0001')
#ax3.plot(ve4, label='0.9')

#ax4.plot(va0, label='0.1')
#ax4.plot(va1, label='0.25')
#ax4.plot(va2, label='0.5')
#ax4.plot(va3, label='0.75')
#ax4.plot(va4, label='0.9')

ax3.legend(loc=2,prop={'size':8})
#ax3.grid()
ax3.set_xlabel('Epoch number')
ax3.set_ylabel('Validation Error')
#ax3.set_yscale('log')
#ax4.legend(loc=2,prop={'size':8})
#ax4.set_xlabel('Epoch number')
#ax4.set_ylabel('Validation Accuracy')
#ax4.set_yscale('log')
#ax4.grid()
fig.tight_layout()
fig.savefig('L2_100.pdf',dpi=200)


print("L2 0.1")
print('    final error(train) = {0}').format(te0[29])
print('    final error(valid) = {0}').format(ve0[29])
print('    final acc(train)   = {0}').format(ta0[29])
print('    final acc(valid)   = {0}').format(va0[29])
print('-------------------------------------------------------------')

print("L2 0.01")
print('    final error(train) = {0}').format(te1[29])
print('    final error(valid) = {0}').format(ve1[29])
print('    final acc(train)   = {0}').format(ta1[29])
print('    final acc(valid)   = {0}').format(va1[29])
print('-------------------------------------------------------------')
            
print("L2 0.001")
print('    final error(train) = {0}').format(te2[29])
print('    final error(valid) = {0}').format(ve2[29])
print('    final acc(train)   = {0}').format(ta2[29])
print('    final acc(valid)   = {0}').format(va2[29])
print('-------------------------------------------------------------')
      
print("L2 0.0001")
print('    final error(train) = {0}').format(te3[29])
print('    final error(valid) = {0}').format(ve3[29])
print('    final acc(train)   = {0}').format(ta3[29])
print('    final acc(valid)   = {0}').format(va3[29])
print('-------------------------------------------------------------')
# Out:
# L2 0.1
#     final error(train) = 0.946003559902
#     final error(valid) = 6.68725061417
#     final acc(train)   = 0.957175000161
#     final acc(valid)   = 0.241799995303
# -------------------------------------------------------------
# L2 0.01
#     final error(train) = 1.45870634437
#     final error(valid) = 6.0799536705
#     final acc(train)   = 0.854774995446
#     final acc(valid)   = 0.220599994063
# -------------------------------------------------------------
# L2 0.001
#     final error(train) = 3.1574642539
#     final error(valid) = 3.09296035767
#     final acc(train)   = 0.305100001125
#     final acc(valid)   = 0.253699988127
# -------------------------------------------------------------
# L2 0.0001
#     final error(train) = 3.94680979043
#     final error(valid) = 3.64271688461
#     final acc(train)   = 0.138149999972
#     final acc(valid)   = 0.144899994135
# -------------------------------------------------------------

# %%
# dropout
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if "baseDA-" in f:
        if "_100" not in f:
#            if "L2" in f:
             print(f)
# Out:
# ../../res/baseDA-brightness_10.txt
# ../../res/baseDA-contrast_10.txt
# ../../res/baseDA-flip_lr_10.txt
# ../../res/baseDA-flip_ud_10.txt
# ../../res/baseDA-hue_10.txt
# ../../res/baseDA-saturation_10.txt

# %%
te0= np.zeros((1,30))
ta0= np.zeros((1,30))
ve0= np.zeros((1,30))
va0= np.zeros((1,30))
te1= np.zeros((1,30))
ta1= np.zeros((1,30))
ve1= np.zeros((1,30))
va1= np.zeros((1,30))
te2= np.zeros((1,30))
ta2= np.zeros((1,30))
ve2= np.zeros((1,30))
va2= np.zeros((1,30))
te3= np.zeros((1,30))
ta3= np.zeros((1,30))
ve3= np.zeros((1,30))
va3= np.zeros((1,30))
te4= np.zeros((1,30))
ta4= np.zeros((1,30))
ve4= np.zeros((1,30))
va4= np.zeros((1,30))
te5= np.zeros((1,30))
ta5= np.zeros((1,30))
ve5= np.zeros((1,30))
va5= np.zeros((1,30))
i = 0
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if "baseDA-" in f:
        if "_100" not in f:
            #if:
                if i==0:
                    te0,ta0,ve0,va0 = get_(read_from_file(f))
                if i==1:
                    te1,ta1,ve1,va1 = get_(read_from_file(f))
                if i==2:
                    te2,ta2,ve2,va2 = get_(read_from_file(f))
                if i==3:
                    te3,ta3,ve3,va3 = get_(read_from_file(f))
                if i==4:
                    te4,ta4,ve4,va4 = get_(read_from_file(f))
                if i==5:
                    te5,ta5,ve5,va5 = get_(read_from_file(f))
                i+=1
                
fig = plt.figure(figsize=(8, 4))
ax1 = fig.add_subplot(1, 2, 1)
#ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(te0, label='brightness')
ax1.plot(te1, label='contrast')
ax1.plot(te2, label='vertical flip')
ax1.plot(te3, label='horizontal flip')
ax1.plot(te4, label='hue')
ax1.plot(te5, label='saturation')

#ax2.plot(ta0, label='0.1')
#ax2.plot(ta1, label='0.25')
#ax2.plot(ta2, label='0.5')
#ax2.plot(ta3, label='0.75')
#ax2.plot(ta4, label='0.9')

ax1.legend(loc=2,prop={'size':8})
#ax1.grid()
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Training Error')
ax1.set_yscale('log')

#ax2.legend(loc=2,prop={'size':8})
#ax2.set_xlabel('Epoch number')
#ax2.set_ylabel('Training Accuracy')
#ax2.set_yscale('log')
#ax2.grid()

ax3 = fig.add_subplot(1, 2, 2)
#ax4 = fig.add_subplot(2, 2, 4)

ax3.plot(ve0, label='brightness')
ax3.plot(ve1, label='contrast')
ax3.plot(ve2, label='vertical flip')
ax3.plot(ve3, label='horizontal flip')
ax3.plot(ve4, label='hue')
ax3.plot(ve5, label='saturation')

#ax4.plot(va0, label='0.1')
#ax4.plot(va1, label='0.25')
#ax4.plot(va2, label='0.5')
#ax4.plot(va3, label='0.75')
#ax4.plot(va4, label='0.9')

ax3.legend(loc=2,prop={'size':8})
#ax3.grid()
ax3.set_xlabel('Epoch number')
ax3.set_ylabel('Validation Error')
#ax3.set_yscale('log')
#ax4.legend(loc=2,prop={'size':8})
#ax4.set_xlabel('Epoch number')
#ax4.set_ylabel('Validation Accuracy')
#ax4.set_yscale('log')
#ax4.grid()
fig.tight_layout()
fig.savefig('DA_10.pdf',dpi=200)


print("Brightness")
print('    final error(train) = {0}').format(te0[29])
print('    final error(valid) = {0}').format(ve0[29])
print('    final acc(train)   = {0}').format(ta0[29])
print('    final acc(valid)   = {0}').format(va0[29])
print('-------------------------------------------------------------')

print("Contrast")
print('    final error(train) = {0}').format(te1[29])
print('    final error(valid) = {0}').format(ve1[29])
print('    final acc(train)   = {0}').format(ta1[29])
print('    final acc(valid)   = {0}').format(va1[29])
print('-------------------------------------------------------------')
            
print("Vertical Flip")
print('    final error(train) = {0}').format(te2[29])
print('    final error(valid) = {0}').format(ve2[29])
print('    final acc(train)   = {0}').format(ta2[29])
print('    final acc(valid)   = {0}').format(va2[29])
print('-------------------------------------------------------------')
      
print("Horizontal Flip")
print('    final error(train) = {0}').format(te3[29])
print('    final error(valid) = {0}').format(ve3[29])
print('    final acc(train)   = {0}').format(ta3[29])
print('    final acc(valid)   = {0}').format(va3[29])
print('-------------------------------------------------------------')

print("Hue")
print('    final error(train) = {0}').format(te4[29])
print('    final error(valid) = {0}').format(ve4[29])
print('    final acc(train)   = {0}').format(ta4[29])
print('    final acc(valid)   = {0}').format(va4[29])
print('-------------------------------------------------------------')
      
print("Saturation")
print('    final error(train) = {0}').format(te5[29])
print('    final error(valid) = {0}').format(ve5[29])
print('    final acc(train)   = {0}').format(ta5[29])
print('    final acc(valid)   = {0}').format(va5[29])
print('-------------------------------------------------------------')
# Out:
# Brightness
#     final error(train) = 0.0130167305061
#     final error(valid) = 4.12356472015
#     final acc(train)   = 0.998700001091
#     final acc(valid)   = 0.552100002766
# -------------------------------------------------------------
# Contrast
#     final error(train) = 0.0176277376428
#     final error(valid) = 3.5817284584
#     final acc(train)   = 0.997950001284
#     final acc(valid)   = 0.569999992847
# -------------------------------------------------------------
# Vertical Flip
#     final error(train) = 0.121500303561
#     final error(valid) = 2.2154147625
#     final acc(train)   = 0.963400000483
#     final acc(valid)   = 0.616400003433
# -------------------------------------------------------------
# Horizontal Flip
#     final error(train) = 0.0155000729815
#     final error(valid) = 3.81268525124
#     final acc(train)   = 0.99812500149
#     final acc(valid)   = 0.566399991512
# -------------------------------------------------------------
# Hue
# ...

# %%
te0= np.zeros((1,30))
ta0= np.zeros((1,30))
ve0= np.zeros((1,30))
va0= np.zeros((1,30))
te1= np.zeros((1,30))
ta1= np.zeros((1,30))
ve1= np.zeros((1,30))
va1= np.zeros((1,30))
te2= np.zeros((1,30))
ta2= np.zeros((1,30))
ve2= np.zeros((1,30))
va2= np.zeros((1,30))
te3= np.zeros((1,30))
ta3= np.zeros((1,30))
ve3= np.zeros((1,30))
va3= np.zeros((1,30))
te4= np.zeros((1,30))
ta4= np.zeros((1,30))
ve4= np.zeros((1,30))
va4= np.zeros((1,30))
te5= np.zeros((1,30))
ta5= np.zeros((1,30))
ve5= np.zeros((1,30))
va5= np.zeros((1,30))
i = 0
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if "baseDA-" in f:
        if "_100" in f:
            #if:
                if i==0:
                    te0,ta0,ve0,va0 = get_(read_from_file(f))
                if i==1:
                    te1,ta1,ve1,va1 = get_(read_from_file(f))
                if i==2:
                    te2,ta2,ve2,va2 = get_(read_from_file(f))
                if i==3:
                    te3,ta3,ve3,va3 = get_(read_from_file(f))
                if i==4:
                    te4,ta4,ve4,va4 = get_(read_from_file(f))
                if i==5:
                    te5,ta5,ve5,va5 = get_(read_from_file(f))
                i+=1
                
fig = plt.figure(figsize=(8, 4))
ax1 = fig.add_subplot(1, 2, 1)
#ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(te0, label='brightness')
ax1.plot(te1, label='contrast')
ax1.plot(te2, label='vertical flip')
ax1.plot(te3, label='horizontal flip')
ax1.plot(te4, label='hue')
ax1.plot(te5, label='saturation')

#ax2.plot(ta0, label='0.1')
#ax2.plot(ta1, label='0.25')
#ax2.plot(ta2, label='0.5')
#ax2.plot(ta3, label='0.75')
#ax2.plot(ta4, label='0.9')

ax1.legend(loc=3,prop={'size':8})
#ax1.grid()
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Training Error')
ax1.set_yscale('log')

#ax2.legend(loc=2,prop={'size':8})
#ax2.set_xlabel('Epoch number')
#ax2.set_ylabel('Training Accuracy')
#ax2.set_yscale('log')
#ax2.grid()

ax3 = fig.add_subplot(1, 2, 2)
#ax4 = fig.add_subplot(2, 2, 4)

ax3.plot(ve0, label='brightness')
ax3.plot(ve1, label='contrast')
ax3.plot(ve2, label='vertical flip')
ax3.plot(ve3, label='horizontal flip')
ax3.plot(ve4, label='hue')
ax3.plot(ve5, label='saturation')

#ax4.plot(va0, label='0.1')
#ax4.plot(va1, label='0.25')
#ax4.plot(va2, label='0.5')
#ax4.plot(va3, label='0.75')
#ax4.plot(va4, label='0.9')

ax3.legend(loc=4,prop={'size':8})
#ax3.grid()
ax3.set_xlabel('Epoch number')
ax3.set_ylabel('Validation Error')
#ax3.set_yscale('log')
#ax4.legend(loc=2,prop={'size':8})
#ax4.set_xlabel('Epoch number')
#ax4.set_ylabel('Validation Accuracy')
#ax4.set_yscale('log')
#ax4.grid()
fig.tight_layout()
fig.savefig('DA_100.pdf',dpi=200)


print("Brightness")
print('    final error(train) = {0}').format(te0[29])
print('    final error(valid) = {0}').format(ve0[29])
print('    final acc(train)   = {0}').format(ta0[29])
print('    final acc(valid)   = {0}').format(va0[29])
print('-------------------------------------------------------------')

print("Contrast")
print('    final error(train) = {0}').format(te1[29])
print('    final error(valid) = {0}').format(ve1[29])
print('    final acc(train)   = {0}').format(ta1[29])
print('    final acc(valid)   = {0}').format(va1[29])
print('-------------------------------------------------------------')
            
print("Vertical Flip")
print('    final error(train) = {0}').format(te2[29])
print('    final error(valid) = {0}').format(ve2[29])
print('    final acc(train)   = {0}').format(ta2[29])
print('    final acc(valid)   = {0}').format(va2[29])
print('-------------------------------------------------------------')
      
print("Horizontal Flip")
print('    final error(train) = {0}').format(te3[29])
print('    final error(valid) = {0}').format(ve3[29])
print('    final acc(train)   = {0}').format(ta3[29])
print('    final acc(valid)   = {0}').format(va3[29])
print('-------------------------------------------------------------')

print("Hue")
print('    final error(train) = {0}').format(te4[29])
print('    final error(valid) = {0}').format(ve4[29])
print('    final acc(train)   = {0}').format(ta4[29])
print('    final acc(valid)   = {0}').format(va4[29])
print('-------------------------------------------------------------')
      
print("Saturation")
print('    final error(train) = {0}').format(te5[29])
print('    final error(valid) = {0}').format(ve5[29])
print('    final acc(train)   = {0}').format(ta5[29])
print('    final acc(valid)   = {0}').format(va5[29])
print('-------------------------------------------------------------')
# Out:
# Brightness
#     final error(train) = 0.0554315323354
#     final error(valid) = 9.79288482666
#     final acc(train)   = 0.990750003904
#     final acc(valid)   = 0.246500000358
# -------------------------------------------------------------
# Contrast
#     final error(train) = 0.0652017837064
#     final error(valid) = 10.1608924866
#     final acc(train)   = 0.988900003806
#     final acc(valid)   = 0.234400004148
# -------------------------------------------------------------
# Vertical Flip
#     final error(train) = 0.0480412672297
#     final error(valid) = 10.4353981018
#     final acc(train)   = 0.992575004697
#     final acc(valid)   = 0.242300003767
# -------------------------------------------------------------
# Horizontal Flip
#     final error(train) = 0.0588231211156
#     final error(valid) = 10.1497631073
#     final acc(train)   = 0.990750003904
#     final acc(valid)   = 0.239199995995
# -------------------------------------------------------------
# Hue
# ...

# %%
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if ("8.txt" in f) or ("16.txt" in f) or ("base-32_10" in f) or ("5-32_10" in f):
        if "_100" not in f:
            print(f)
# Out:
# ../../res/base16.txt
# ../../res/base-32_10.txt
# ../../res/base8.txt
# ../../res/baseK5-16.txt
# ../../res/baseK5-32_10.txt
# ../../res/baseK5-8.txt

# %%
te0= np.zeros((1,30))
ta0= np.zeros((1,30))
ve0= np.zeros((1,30))
va0= np.zeros((1,30))
te1= np.zeros((1,30))
ta1= np.zeros((1,30))
ve1= np.zeros((1,30))
va1= np.zeros((1,30))
te2= np.zeros((1,30))
ta2= np.zeros((1,30))
ve2= np.zeros((1,30))
va2= np.zeros((1,30))
te3= np.zeros((1,30))
ta3= np.zeros((1,30))
ve3= np.zeros((1,30))
va3= np.zeros((1,30))
te4= np.zeros((1,30))
ta4= np.zeros((1,30))
ve4= np.zeros((1,30))
va4= np.zeros((1,30))
te5= np.zeros((1,30))
ta5= np.zeros((1,30))
ve5= np.zeros((1,30))
va5= np.zeros((1,30))
i = 0
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if ("8.txt" in f) or ("16.txt" in f) or ("base-32_10" in f) or ("5-32_10" in f):
        if "_100" not in f:
                if i==0:
                    te0,ta0,ve0,va0 = get_(read_from_file(f))
                if i==1:
                    te1,ta1,ve1,va1 = get_(read_from_file(f))
                if i==2:
                    te2,ta2,ve2,va2 = get_(read_from_file(f))
                if i==3:
                    te3,ta3,ve3,va3 = get_(read_from_file(f))
                if i==4:
                    te4,ta4,ve4,va4 = get_(read_from_file(f))
                if i==5:
                    te5,ta5,ve5,va5 = get_(read_from_file(f))
                i+=1
                
fig = plt.figure(figsize=(8, 4))
ax1 = fig.add_subplot(1, 2, 1)
#ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(te0, label='2x2 x16')
ax1.plot(te1, label='2x2 x32')
ax1.plot(te2, label='2x2 x8')
ax1.plot(te3, label='5x5 x16')
ax1.plot(te4, label='5x5 x32')
ax1.plot(te4, label='5x5 x8')

#ax2.plot(ta0, label='0.1')
#ax2.plot(ta1, label='0.25')
#ax2.plot(ta2, label='0.5')
#ax2.plot(ta3, label='0.75')
#ax2.plot(ta4, label='0.9')

ax1.legend(loc=1,prop={'size':8})
#ax1.grid()
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Training Error')
ax1.set_yscale('log')

#ax2.legend(loc=2,prop={'size':8})
#ax2.set_xlabel('Epoch number')
#ax2.set_ylabel('Training Accuracy')
#ax2.set_yscale('log')
#ax2.grid()

ax3 = fig.add_subplot(1, 2, 2)
#ax4 = fig.add_subplot(2, 2, 4)

ax3.plot(ve0, label='2x2 x16')
ax3.plot(ve1, label='2x2 x32')
ax3.plot(ve2, label='2x2 x8')
ax3.plot(ve3, label='5x5 x16')
ax3.plot(ve4, label='5x5 x32')
ax3.plot(ve4, label='5x5 x8')

#ax4.plot(va0, label='0.1')
#ax4.plot(va1, label='0.25')
#ax4.plot(va2, label='0.5')
#ax4.plot(va3, label='0.75')
#ax4.plot(va4, label='0.9')

ax3.legend(loc=2,prop={'size':8})
#ax3.grid()
ax3.set_xlabel('Epoch number')
ax3.set_ylabel('Validation Error')
#ax3.set_yscale('log')
#ax4.legend(loc=2,prop={'size':8})
#ax4.set_xlabel('Epoch number')
#ax4.set_ylabel('Validation Accuracy')
#ax4.set_yscale('log')
#ax4.grid()
fig.tight_layout()
fig.savefig('2x2or5x5_10.pdf',dpi=200)


print("2x2 x16")
print('    final error(train) = {0}').format(te0[29])
print('    final error(valid) = {0}').format(ve0[29])
print('    final acc(train)   = {0}').format(ta0[29])
print('    final acc(valid)   = {0}').format(va0[29])
print('-------------------------------------------------------------')

print("2x2 x32")
print('    final error(train) = {0}').format(te1[29])
print('    final error(valid) = {0}').format(ve1[29])
print('    final acc(train)   = {0}').format(ta1[29])
print('    final acc(valid)   = {0}').format(va1[29])
print('-------------------------------------------------------------')
            
print("2x2 x8")
print('    final error(train) = {0}').format(te2[29])
print('    final error(valid) = {0}').format(ve2[29])
print('    final acc(train)   = {0}').format(ta2[29])
print('    final acc(valid)   = {0}').format(va2[29])
print('-------------------------------------------------------------')
      
print("5x5 x16")
print('    final error(train) = {0}').format(te3[29])
print('    final error(valid) = {0}').format(ve3[29])
print('    final acc(train)   = {0}').format(ta3[29])
print('    final acc(valid)   = {0}').format(va3[29])
print('-------------------------------------------------------------')
      
print("5x5 x32")
print('    final error(train) = {0}').format(te4[29])
print('    final error(valid) = {0}').format(ve4[29])
print('    final acc(train)   = {0}').format(ta4[29])
print('    final acc(valid)   = {0}').format(va4[29])
print('-------------------------------------------------------------')

print("5x5 x8")
print('    final error(train) = {0}').format(te4[29])
print('    final error(valid) = {0}').format(ve4[29])
print('    final acc(train)   = {0}').format(ta4[29])
print('    final acc(valid)   = {0}').format(va4[29])
print('-------------------------------------------------------------')
# Out:
# 2x2 x16
#     final error(train) = 0.0396707262464
#     final error(valid) = 3.8598484993
#     final acc(train)   = 0.988125004396
#     final acc(valid)   = 0.573700010777
# -------------------------------------------------------------
# 2x2 x32
#     final error(train) = 0.060421610504
#     final error(valid) = 3.84680938721
#     final acc(train)   = 0.983425003663
#     final acc(valid)   = 0.555199980736
# -------------------------------------------------------------
# 2x2 x8
#     final error(train) = 0.0494231136517
#     final error(valid) = 3.53452706337
#     final acc(train)   = 0.983150003478
#     final acc(valid)   = 0.583400011063
# -------------------------------------------------------------
# 5x5 x16
#     final error(train) = 0.0719930402783
#     final error(valid) = 4.39237976074
#     final acc(train)   = 0.980500003248
#     final acc(valid)   = 0.503499984741
# -------------------------------------------------------------
# 5x5 x32
# ...

# %%
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if ("8_100" in f) or ("16_100" in f) or ("base-32_100" in f) or ("5-32_100" in f):
        if "6CNN" not in f and "avg" not in f:
            print(f)
# Out:
# ../../res/base16_100.txt
# ../../res/base-32_100.txt
# ../../res/base8_100.txt
# ../../res/baseK5-16_100.txt
# ../../res/baseK5-32_100.txt
# ../../res/baseK5-8_100.txt

# %%
te0= np.zeros((1,30))
ta0= np.zeros((1,30))
ve0= np.zeros((1,30))
va0= np.zeros((1,30))
te1= np.zeros((1,30))
ta1= np.zeros((1,30))
ve1= np.zeros((1,30))
va1= np.zeros((1,30))
te2= np.zeros((1,30))
ta2= np.zeros((1,30))
ve2= np.zeros((1,30))
va2= np.zeros((1,30))
te3= np.zeros((1,30))
ta3= np.zeros((1,30))
ve3= np.zeros((1,30))
va3= np.zeros((1,30))
te4= np.zeros((1,30))
ta4= np.zeros((1,30))
ve4= np.zeros((1,30))
va4= np.zeros((1,30))
te5= np.zeros((1,30))
ta5= np.zeros((1,30))
ve5= np.zeros((1,30))
va5= np.zeros((1,30))
i = 0
for fname in os.listdir(path):
    f = os.path.join(path, fname)
    if ("8_100" in f) or ("16_100" in f) or ("base-32_100" in f) or ("5-32_100" in f):
        if "6CNN" not in f and "avg" not in f:
                if i==0:
                    te0,ta0,ve0,va0 = get_(read_from_file(f))
                if i==1:
                    te1,ta1,ve1,va1 = get_(read_from_file(f))
                if i==2:
                    te2,ta2,ve2,va2 = get_(read_from_file(f))
                if i==3:
                    te3,ta3,ve3,va3 = get_(read_from_file(f))
                if i==4:
                    te4,ta4,ve4,va4 = get_(read_from_file(f))
                if i==5:
                    te5,ta5,ve5,va5 = get_(read_from_file(f))
                i+=1
                
fig = plt.figure(figsize=(8, 4))
ax1 = fig.add_subplot(1, 2, 1)
#ax2 = fig.add_subplot(2, 2, 2)

ax1.plot(te0, label='2x2 x16')
ax1.plot(te1, label='2x2 x32')
ax1.plot(te2, label='2x2 x8')
ax1.plot(te3, label='5x5 x16')
ax1.plot(te4, label='5x5 x32')
ax1.plot(te4, label='5x5 x8')

#ax2.plot(ta0, label='0.1')
#ax2.plot(ta1, label='0.25')
#ax2.plot(ta2, label='0.5')
#ax2.plot(ta3, label='0.75')
#ax2.plot(ta4, label='0.9')

ax1.legend(loc=1,prop={'size':8})
#ax1.grid()
ax1.set_xlabel('Epoch number')
ax1.set_ylabel('Training Error')
ax1.set_yscale('log')

#ax2.legend(loc=2,prop={'size':8})
#ax2.set_xlabel('Epoch number')
#ax2.set_ylabel('Training Accuracy')
#ax2.set_yscale('log')
#ax2.grid()

ax3 = fig.add_subplot(1, 2, 2)
#ax4 = fig.add_subplot(2, 2, 4)

ax3.plot(ve0, label='2x2 x16')
ax3.plot(ve1, label='2x2 x32')
ax3.plot(ve2, label='2x2 x8')
ax3.plot(ve3, label='5x5 x16')
ax3.plot(ve4, label='5x5 x32')
ax3.plot(ve4, label='5x5 x8')

#ax4.plot(va0, label='0.1')
#ax4.plot(va1, label='0.25')
#ax4.plot(va2, label='0.5')
#ax4.plot(va3, label='0.75')
#ax4.plot(va4, label='0.9')

ax3.legend(loc=2,prop={'size':8})
#ax3.grid()
ax3.set_xlabel('Epoch number')
ax3.set_ylabel('Validation Error')
#ax3.set_yscale('log')
#ax4.legend(loc=2,prop={'size':8})
#ax4.set_xlabel('Epoch number')
#ax4.set_ylabel('Validation Accuracy')
#ax4.set_yscale('log')
#ax4.grid()
fig.tight_layout()
fig.savefig('2x2or5x5_100.pdf',dpi=200)


print("2x2 x16")
print('    final error(train) = {0}').format(te0[29])
print('    final error(valid) = {0}').format(ve0[29])
print('    final acc(train)   = {0}').format(ta0[29])
print('    final acc(valid)   = {0}').format(va0[29])
print('-------------------------------------------------------------')

print("2x2 x32")
print('    final error(train) = {0}').format(te1[29])
print('    final error(valid) = {0}').format(ve1[29])
print('    final acc(train)   = {0}').format(ta1[29])
print('    final acc(valid)   = {0}').format(va1[29])
print('-------------------------------------------------------------')
            
print("2x2 x8")
print('    final error(train) = {0}').format(te2[29])
print('    final error(valid) = {0}').format(ve2[29])
print('    final acc(train)   = {0}').format(ta2[29])
print('    final acc(valid)   = {0}').format(va2[29])
print('-------------------------------------------------------------')
      
print("5x5 x16")
print('    final error(train) = {0}').format(te3[29])
print('    final error(valid) = {0}').format(ve3[29])
print('    final acc(train)   = {0}').format(ta3[29])
print('    final acc(valid)   = {0}').format(va3[29])
print('-------------------------------------------------------------')
      
print("5x5 x32")
print('    final error(train) = {0}').format(te4[29])
print('    final error(valid) = {0}').format(ve4[29])
print('    final acc(train)   = {0}').format(ta4[29])
print('    final acc(valid)   = {0}').format(va4[29])
print('-------------------------------------------------------------')

print("5x5 x8")
print('    final error(train) = {0}').format(te4[29])
print('    final error(valid) = {0}').format(ve4[29])
print('    final acc(train)   = {0}').format(ta4[29])
print('    final acc(valid)   = {0}').format(va4[29])
print('-------------------------------------------------------------')
# Out:
# 2x2 x16
#     final error(train) = 0.0567701179564
#     final error(valid) = 9.57557296753
#     final acc(train)   = 0.983625003397
#     final acc(valid)   = 0.25720000267
# -------------------------------------------------------------
# 2x2 x32
#     final error(train) = 0.0865533510919
#     final error(valid) = 10.9012269974
#     final acc(train)   = 0.980150003359
#     final acc(valid)   = 0.203500002623
# -------------------------------------------------------------
# 2x2 x8
#     final error(train) = 0.185031652147
#     final error(valid) = 9.8001499176
#     final acc(train)   = 0.94144999817
#     final acc(valid)   = 0.249300003052
# -------------------------------------------------------------
# 5x5 x16
#     final error(train) = 0.0973173923828
#     final error(valid) = 12.849852562
#     final acc(train)   = 0.974825002253
#     final acc(valid)   = 0.213300004601
# -------------------------------------------------------------
# 5x5 x32
# ...

# %%
from mlp.data_providers import CIFAR10DataProvider, CIFAR100DataProvider
import matplotlib.pyplot as plt
# %matplotlib inline
import random

train_data = CIFAR10DataProvider('train', batch_size=50)
valid_data = CIFAR10DataProvider('valid', batch_size=50)

# %%
def pre_process(x, trans):
    if (trans == 'flip_ud'):
        x = tf.map_fn(lambda image: pre_process_test(image), x)
    elif (trans == 'flip_lr'):
        x = tf.map_fn(lambda image: pre_process_image_flip_lr(image), x)
    elif (trans == 'hue'):
        x = tf.map_fn(lambda image: pre_process_image_hue(image), x)
    elif (trans == 'contrast'):
        x = tf.map_fn(lambda image: pre_process_image_contrast(image), x)
    elif (trans == 'brightness'):
        x = tf.map_fn(lambda image: pre_process_image_brightness(image), x)
    elif (trans == 'saturation'):
        x = tf.map_fn(lambda image: pre_process_image_saturation(image), x)
    else:
        print('No transformation used')

    return x

# %%
def pre_process_flip_ud(image):
    image = tf.reshape(image,[32,32,3])

    choice = random.randint(0, 3)
    if (choice == 0):
        image = tf.image.random_flip_left_right(image)
        #image = tf.image.random_flip_up_down(image)
        # Randomly adjust hue, contrast and saturation.
        image = tf.image.random_hue(image, max_delta=0.05)
        image = tf.image.random_contrast(image, lower=0.3, upper=1.0)
        image = tf.image.random_brightness(image, max_delta=0.2)
        image = tf.image.random_saturation(image, lower=0.0, upper=2.0)

        # Limit the image pixels between [0, 1] in case of overflow.
        image = tf.minimum(image, 1.0)
        image = tf.maximum(image, 0.0)

    return tf.reshape(image,[-1])

def pre_process_image_hue(image):
    image = tf.reshape(image,[32,32,3])
    # Randomly adjust hue, contrast and saturation.
    choice = random.randint(0, 3)
    if (choice == 0):
        image = tf.image.random_hue(image, max_delta=0.05)
        # Limit the image pixels between [0, 1] in case of overflow.
        image = tf.minimum(image, 1.0)
        image = tf.maximum(image, 0.0)
    return tf.reshape(image,[-1])

# %%
# %matplotlib inline

sess = tf.InteractiveSession()

im = input_batch[45,:].reshape(3072,1)
im_ = np.reshape(im, (32,32,3), order='F')
#plt.imshow(im_)

im2 = pre_process_flip_ud(im2)
im2.eval()
#plt.imshow(im2)
# Out:
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# <ipython-input-91-96533b207f90> in <module>()
#       8
#       9 im2 = pre_process_flip_ud(im2)
# ---> 10 im2.eval()
#      11 #plt.imshow(im2)
#
# /afs/inf.ed.ac.uk/user/s16/s1641718/miniconda2/envs/mlp/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in eval(self, feed_dict, session)
#     573
#     574     """
# --> 575     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     576
#     577
#
# /afs/inf.ed.ac.uk/user/s16/s1641718/miniconda2/envs/mlp/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in _eval_using_default_session(tensors, feed_dict, graph, session)
#    3631                        "the tensor's graph is different from the session's "
#    3632                        "graph.")
# -> 3633   return session.run(tensors, feed_dict)
#    3634
#    3635
#
# ...
